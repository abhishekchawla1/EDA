# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\ASUS\Downloads\test.csv")

# %%
df.head(5)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df.tail(3)
# Out:
#      PassengerId  Pclass                          Name   Sex   Age  SibSp  \
# 415         1307       3  Saether, Mr. Simon Sivertsen  male  38.5      0
# 416         1308       3           Ware, Mr. Frederick  male   NaN      0
# 417         1309       3      Peter, Master. Michael J  male   NaN      1
#
#      Parch              Ticket     Fare Cabin Embarked
# 415      0  SOTON/O.Q. 3101262   7.2500   NaN        S
# 416      0              359309   8.0500   NaN        S
# 417      1                2668  22.3583   NaN        C

# %%
rows,columns=df.shape

# %%
rows
# Out:
# 418

# %%
columns
# Out:
# 11

# %%
df.shape
# Out:
# (418, 11)

# %%
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
df.duplicated().any()
# Out:
# False

# %%
df.index
# Out:
# RangeIndex(start=0, stop=418, step=1)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 11

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
df.describe(include='all')
# Out:
#         PassengerId      Pclass              Name   Sex         Age  \
# count    418.000000  418.000000               418   418  332.000000
# unique          NaN         NaN               418     2         NaN
# top             NaN         NaN  Kelly, Mr. James  male         NaN
# freq            NaN         NaN                 1   266         NaN
# mean    1100.500000    2.265550               NaN   NaN   30.272590
# std      120.810458    0.841838               NaN   NaN   14.181209
# min      892.000000    1.000000               NaN   NaN    0.170000
# 25%      996.250000    1.000000               NaN   NaN   21.000000
# 50%     1100.500000    3.000000               NaN   NaN   27.000000
# 75%     1204.750000    3.000000               NaN   NaN   39.000000
# max     1309.000000    3.000000               NaN   NaN   76.000000
#
#              SibSp       Parch    Ticket        Fare            Cabin Embarked
# count   418.000000  418.000000       418  417.000000               91      418
# unique         NaN         NaN       363         NaN               76        3
# top            NaN         NaN  PC 17608         NaN  B57 B59 B63 B66        S
# freq           NaN         NaN         5         NaN                3      270
# mean      0.447368    0.392344       NaN   35.627188              NaN      NaN
# std       0.896760    0.981429       NaN   55.907576              NaN      NaN
# min       0.000000    0.000000       NaN    0.000000              NaN      NaN
# 25%       0.000000    0.000000       NaN    7.895800              NaN      NaN
# 50%       0.000000    0.000000       NaN   14.454200              NaN      NaN
# 75%       1.000000    0.000000       NaN   31.500000              NaN      NaN
# max       8.000000    9.000000       NaN  512.329200              NaN      NaN

# %%
df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
sum(df['Sex']=='male')
# Out:
# 266

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
per=df.isnull().sum()*100/len(df)

# %%
per
# Out:
# PassengerId     0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            20.574163
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.239234
# Cabin          78.229665
# Embarked        0.000000
# dtype: float64

# %%
df.drop('Cabin',axis=1,inplace=True)

# %%
len(df.columns)
# Out:
# 10

# %%
df.isnull().sum()
# Out:
# PassengerId     0
# Pclass          0
# Name            0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Ticket          0
# Fare            1
# Embarked        0
# dtype: int64

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Embarked
# 0      male  34.5      0      0              330911    7.8292        Q
# 1    female  47.0      1      0              363272    7.0000        S
# 2      male  62.0      0      0              240276    9.6875        Q
# 3      male  27.0      0      0              315154    8.6625        S
# 4    female  22.0      1      1             3101298   12.2875        S
# ..      ...   ...    ...    ...                 ...       ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500        S
# 414  female  39.0      0      0            PC 17758  108.9000        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500        S
# 416    male   NaN      0      0              359309    8.0500        S
# 417    male   NaN      1      1                2668   22.3583        C
#
# [418 rows x 10 columns]

# %%
df['Fare']
# Out:
# 0        7.8292
# 1        7.0000
# 2        9.6875
# 3        8.6625
# 4       12.2875
#          ...
# 413      8.0500
# 414    108.9000
# 415      7.2500
# 416      8.0500
# 417     22.3583
# Name: Fare, Length: 418, dtype: float64

# %%
df['Fare'].mean()
# Out:
# 35.627188489208635

# %%
df['Fare']=df['Fare'].fillna(df['Fare'].mean())

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Embarked
# 0      male  34.5      0      0              330911    7.8292        Q
# 1    female  47.0      1      0              363272    7.0000        S
# 2      male  62.0      0      0              240276    9.6875        Q
# 3      male  27.0      0      0              315154    8.6625        S
# 4    female  22.0      1      1             3101298   12.2875        S
# ..      ...   ...    ...    ...                 ...       ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500        S
# 414  female  39.0      0      0            PC 17758  108.9000        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500        S
# 416    male   NaN      0      0              359309    8.0500        S
# 417    male   NaN      1      1                2668   22.3583        C
#
# [418 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId     0
# Pclass          0
# Name            0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Embarked        0
# dtype: int64

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['Gender']=df['Sex'].map({'male':1,'female':0})

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex       Age  SibSp  Parch              Ticket      Fare Embarked  \
# 0      male  34.50000      0      0              330911    7.8292        Q
# 1    female  47.00000      1      0              363272    7.0000        S
# 2      male  62.00000      0      0              240276    9.6875        Q
# 3      male  27.00000      0      0              315154    8.6625        S
# 4    female  22.00000      1      1             3101298   12.2875        S
# ..      ...       ...    ...    ...                 ...       ...      ...
# 413    male  30.27259      0      0           A.5. 3236    8.0500        S
# 414  female  39.00000      0      0            PC 17758  108.9000        C
# 415    male  38.50000      0      0  SOTON/O.Q. 3101262    7.2500        S
# 416    male  30.27259      0      0              359309    8.0500        S
# 417    male  30.27259      1      1                2668   22.3583        C
#
#      Gender
# 0         1
# 1         0
# 2         1
# 3         1
# 4         0
# ..      ...
# 413       1
# 414       0
# 415       1
# 416       1
# 417       1
#
# [418 rows x 11 columns]

# %%
df.insert(5,'g',df['Sex'].map({'male':1,'female':0}))

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex       Age  g  SibSp  Parch              Ticket      Fare Embarked  \
# 0      male  34.50000  1      0      0              330911    7.8292        Q
# 1    female  47.00000  0      1      0              363272    7.0000        S
# 2      male  62.00000  1      0      0              240276    9.6875        Q
# 3      male  27.00000  1      0      0              315154    8.6625        S
# 4    female  22.00000  0      1      1             3101298   12.2875        S
# ..      ...       ... ..    ...    ...                 ...       ...      ...
# 413    male  30.27259  1      0      0           A.5. 3236    8.0500        S
# 414  female  39.00000  0      0      0            PC 17758  108.9000        C
# 415    male  38.50000  1      0      0  SOTON/O.Q. 3101262    7.2500        S
# 416    male  30.27259  1      0      0              359309    8.0500        S
# 417    male  30.27259  1      1      1                2668   22.3583        C
#
#      Gender
# 0         1
# 1         0
# 2         1
# 3         1
# 4         0
# ..      ...
# 413       1
# 414       0
# 415       1
# 416       1
# 417       1
#
# [418 rows x 12 columns]

# %%
df.drop(columns='Gender',inplace=True)

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex       Age  g  SibSp  Parch              Ticket      Fare Embarked
# 0      male  34.50000  1      0      0              330911    7.8292        Q
# 1    female  47.00000  0      1      0              363272    7.0000        S
# 2      male  62.00000  1      0      0              240276    9.6875        Q
# 3      male  27.00000  1      0      0              315154    8.6625        S
# 4    female  22.00000  0      1      1             3101298   12.2875        S
# ..      ...       ... ..    ...    ...                 ...       ...      ...
# 413    male  30.27259  1      0      0           A.5. 3236    8.0500        S
# 414  female  39.00000  0      0      0            PC 17758  108.9000        C
# 415    male  38.50000  1      0      0  SOTON/O.Q. 3101262    7.2500        S
# 416    male  30.27259  1      0      0              359309    8.0500        S
# 417    male  30.27259  1      1      1                2668   22.3583        C
#
# [418 rows x 11 columns]

# %%
df['Embarked'].nunique()
# Out:
# 3

# %%
pd.get_dummies(df,columns=['Embarked'])
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex       Age  g  SibSp  Parch              Ticket      Fare  \
# 0      male  34.50000  1      0      0              330911    7.8292
# 1    female  47.00000  0      1      0              363272    7.0000
# 2      male  62.00000  1      0      0              240276    9.6875
# 3      male  27.00000  1      0      0              315154    8.6625
# 4    female  22.00000  0      1      1             3101298   12.2875
# ..      ...       ... ..    ...    ...                 ...       ...
# 413    male  30.27259  1      0      0           A.5. 3236    8.0500
# 414  female  39.00000  0      0      0            PC 17758  108.9000
# 415    male  38.50000  1      0      0  SOTON/O.Q. 3101262    7.2500
# 416    male  30.27259  1      0      0              359309    8.0500
# 417    male  30.27259  1      1      1                2668   22.3583
#
#      Embarked_C  Embarked_Q  Embarked_S
# 0             0           1           0
# 1             0           0           1
# 2             0           1           0
# 3             0           0           1
# 4             0           0           1
# ..          ...         ...         ...
# 413           0           0           1
# 414           1           0           0
# 415           0           0           1
# 416           0           0           1
# 417           1           0           0
#
# [418 rows x 13 columns]

# %%
df['Pclass'].value_counts()
# Out:
# 3    218
# 1    107
# 2     93
# Name: Pclass, dtype: int64

# %%
df['Sex'].value_counts()
# Out:
# male      266
# female    152
# Name: Sex, dtype: int64

# %%
sns.countplot(df['g'])
# Out:
# <Axes: ylabel='count'>

# %%
plt.hist(df['Age'])
# Out:
# (array([ 16.,  16.,  71., 183.,  43.,  37.,  25.,  17.,   9.,   1.]),
#  array([ 0.17 ,  7.753, 15.336, 22.919, 30.502, 38.085, 45.668, 53.251,
#         60.834, 68.417, 76.   ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'g', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
df['FamSize']=df['SibSp']+df['Parch']

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex       Age  g  SibSp  Parch              Ticket      Fare Embarked  \
# 0      male  34.50000  1      0      0              330911    7.8292        Q
# 1    female  47.00000  0      1      0              363272    7.0000        S
# 2      male  62.00000  1      0      0              240276    9.6875        Q
# 3      male  27.00000  1      0      0              315154    8.6625        S
# 4    female  22.00000  0      1      1             3101298   12.2875        S
# ..      ...       ... ..    ...    ...                 ...       ...      ...
# 413    male  30.27259  1      0      0           A.5. 3236    8.0500        S
# 414  female  39.00000  0      0      0            PC 17758  108.9000        C
# 415    male  38.50000  1      0      0  SOTON/O.Q. 3101262    7.2500        S
# 416    male  30.27259  1      0      0              359309    8.0500        S
# 417    male  30.27259  1      1      1                2668   22.3583        C
#
#      FamSize
# 0          0
# 1          1
# 2          0
# 3          0
# 4          2
# ..       ...
# 413        0
# 414        0
# 415        0
# 416        0
# 417        2
#
# [418 rows x 12 columns]

# %%
df['F/P']=df['Fare']/(df['FamSize']+1)

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex       Age  g  SibSp  Parch              Ticket      Fare Embarked  \
# 0      male  34.50000  1      0      0              330911    7.8292        Q
# 1    female  47.00000  0      1      0              363272    7.0000        S
# 2      male  62.00000  1      0      0              240276    9.6875        Q
# 3      male  27.00000  1      0      0              315154    8.6625        S
# 4    female  22.00000  0      1      1             3101298   12.2875        S
# ..      ...       ... ..    ...    ...                 ...       ...      ...
# 413    male  30.27259  1      0      0           A.5. 3236    8.0500        S
# 414  female  39.00000  0      0      0            PC 17758  108.9000        C
# 415    male  38.50000  1      0      0  SOTON/O.Q. 3101262    7.2500        S
# 416    male  30.27259  1      0      0              359309    8.0500        S
# 417    male  30.27259  1      1      1                2668   22.3583        C
#
#      FamSize         F/P
# 0          0    7.829200
# 1          1    3.500000
# 2          0    9.687500
# 3          0    8.662500
# 4          2    4.095833
# ..       ...         ...
# 413        0    8.050000
# 414        0  108.900000
# 415        0    7.250000
# 416        0    8.050000
# 417        2    7.452767
#
# [418 rows x 13 columns]
