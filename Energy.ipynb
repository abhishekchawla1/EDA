# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel(r"C:\Users\ASUS\Downloads\Energy Indicators.xls")

# %%
df=df.iloc[17:]

# %%
df
# Out:
#      Unnamed: 0                                         Unnamed: 1  \
# 17          NaN                                        Afghanistan
# 18          NaN                                            Albania
# 19          NaN                                            Algeria
# 20          NaN                                     American Samoa
# 21          NaN                                            Andorra
# ..          ...                                                ...
# 277         NaN                       … denotes no data available.
# 278         NaN                                                NaN
# 279         NaN                                     Data Quality:
# 280         NaN  The data are compiled primarily from the annua...
# 281         NaN  For more information, visit http://unstats.un....
#
#          Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 17      Afghanistan        321         10   78.66928
# 18          Albania        102         35        100
# ...

# %%
df.drop(columns=['Unnamed: 0','Unnamed: 1'], inplace=True)

# %%
df
# Out:
#          Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 17      Afghanistan        321         10   78.66928
# 18          Albania        102         35        100
# 19          Algeria       1959         51    0.55101
# 20   American Samoa        ...        ...   0.641026
# 21          Andorra          9        121   88.69565
# ..              ...        ...        ...        ...
# 277             NaN        NaN        NaN        NaN
# 278             NaN        NaN        NaN        NaN
# 279             NaN        NaN        NaN        NaN
# 280             NaN        NaN        NaN        NaN
# 281             NaN        NaN        NaN        NaN
#
# [265 rows x 4 columns]

# %%
df=df.rename(columns={'Unnamed: 2':'Country','Unnamed: 3':'Energy Supply','Unnamed: 4':'Energy Supply per Capita','Unnamed: 5':'% Renewable'})

# %%
df
# Out:
#             Country Energy Supply Energy Supply per Capita % Renewable
# 17      Afghanistan           321                       10    78.66928
# 18          Albania           102                       35         100
# 19          Algeria          1959                       51     0.55101
# 20   American Samoa           ...                      ...    0.641026
# 21          Andorra             9                      121    88.69565
# ..              ...           ...                      ...         ...
# 277             NaN           NaN                      NaN         NaN
# 278             NaN           NaN                      NaN         NaN
# 279             NaN           NaN                      NaN         NaN
# 280             NaN           NaN                      NaN         NaN
# 281             NaN           NaN                      NaN         NaN
#
# [265 rows x 4 columns]

# %%
df.replace('...',np.nan,inplace=True)

# %%
df
# Out:
#             Country  Energy Supply  Energy Supply per Capita  % Renewable
# 17      Afghanistan          321.0                      10.0    78.669280
# 18          Albania          102.0                      35.0   100.000000
# 19          Algeria         1959.0                      51.0     0.551010
# 20   American Samoa            NaN                       NaN     0.641026
# 21          Andorra            9.0                     121.0    88.695650
# ..              ...            ...                       ...          ...
# 277             NaN            NaN                       NaN          NaN
# 278             NaN            NaN                       NaN          NaN
# 279             NaN            NaN                       NaN          NaN
# 280             NaN            NaN                       NaN          NaN
# 281             NaN            NaN                       NaN          NaN
#
# [265 rows x 4 columns]

# %%
df['Energy Supply']*=1000000

# %%
df
# Out:
#             Country  Energy Supply  Energy Supply per Capita  % Renewable
# 17      Afghanistan   3.210000e+08                      10.0    78.669280
# 18          Albania   1.020000e+08                      35.0   100.000000
# 19          Algeria   1.959000e+09                      51.0     0.551010
# 20   American Samoa            NaN                       NaN     0.641026
# 21          Andorra   9.000000e+06                     121.0    88.695650
# ..              ...            ...                       ...          ...
# 277             NaN            NaN                       NaN          NaN
# 278             NaN            NaN                       NaN          NaN
# 279             NaN            NaN                       NaN          NaN
# 280             NaN            NaN                       NaN          NaN
# 281             NaN            NaN                       NaN          NaN
#
# [265 rows x 4 columns]

# %%
df['Country']=df['Country'].replace({"Republic of Korea": "South Korea", "United States of America": "United States", "United Kingdom of Great Britain and Northern Ireland": "United Kingdom", "China, Hong Kong Special Administrative Region": "Hong Kong"})

# %%
df.Country.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia1', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia (Plurinational State of)',
#        'Bonaire, Sint Eustatius and Saba', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Chile', 'China2',
#        'China, Hong Kong Special Administrative Region3',
#        'China, Macao Special Administrative Region4', 'Colombia',
#        'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', "Côte d'Ivoire",
#        'Croatia', 'Cuba', 'Curaçao', 'Cyprus', 'Czech Republic',
# ...

# %%
def first(x):
    return x.split('(')[0].strip()

# %%
df.dtypes
# Out:
# Country                      object
# Energy Supply               float64
# Energy Supply per Capita    float64
# % Renewable                 float64
# dtype: object

# %%
df['Country']=df['Country'].astype(str)

# %%
df.dtypes
# Out:
# Country                      object
# Energy Supply               float64
# Energy Supply per Capita    float64
# % Renewable                 float64
# dtype: object

# %%
df['Country']=df['Country'].apply(first)

# %%
df['Country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia1', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia',
#        'Bonaire, Sint Eustatius and Saba', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Chile', 'China2',
#        'China, Hong Kong Special Administrative Region3',
#        'China, Macao Special Administrative Region4', 'Colombia',
#        'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', "Côte d'Ivoire",
#        'Croatia', 'Cuba', 'Curaçao', 'Cyprus', 'Czech Republic',
# ...

# %%
df
# Out:
#             Country  Energy Supply  Energy Supply per Capita  % Renewable
# 17      Afghanistan   3.210000e+08                      10.0    78.669280
# 18          Albania   1.020000e+08                      35.0   100.000000
# 19          Algeria   1.959000e+09                      51.0     0.551010
# 20   American Samoa            NaN                       NaN     0.641026
# 21          Andorra   9.000000e+06                     121.0    88.695650
# ..              ...            ...                       ...          ...
# 277             nan            NaN                       NaN          NaN
# 278             nan            NaN                       NaN          NaN
# 279             nan            NaN                       NaN          NaN
# 280             nan            NaN                       NaN          NaN
# 281             nan            NaN                       NaN          NaN
#
# [265 rows x 4 columns]

# %%
import re
def second(x):
    return re.sub(r'\d','',x)

# %%
df['Country']=df['Country'].apply(second)

# %%
df
# Out:
#             Country  Energy Supply  Energy Supply per Capita  % Renewable
# 17      Afghanistan   3.210000e+08                      10.0    78.669280
# 18          Albania   1.020000e+08                      35.0   100.000000
# 19          Algeria   1.959000e+09                      51.0     0.551010
# 20   American Samoa            NaN                       NaN     0.641026
# 21          Andorra   9.000000e+06                     121.0    88.695650
# ..              ...            ...                       ...          ...
# 277             nan            NaN                       NaN          NaN
# 278             nan            NaN                       NaN          NaN
# 279             nan            NaN                       NaN          NaN
# 280             nan            NaN                       NaN          NaN
# 281             nan            NaN                       NaN          NaN
#
# [265 rows x 4 columns]

# %%
df2=pd.read_csv(r"C:\Users\ASUS\Downloads\world_bank.csv",skiprows=4)

# %%
df2
# Out:
#          Country Name Country Code                            Indicator Name  \
# 0               Aruba          ABW  GDP at market prices (constant 2010 US$)
# 1             Andorra          AND  GDP at market prices (constant 2010 US$)
# 2         Afghanistan          AFG  GDP at market prices (constant 2010 US$)
# 3              Angola          AGO  GDP at market prices (constant 2010 US$)
# 4             Albania          ALB  GDP at market prices (constant 2010 US$)
# ..                ...          ...                                       ...
# 259       Yemen, Rep.          YEM  GDP at market prices (constant 2010 US$)
# 260      South Africa          ZAF  GDP at market prices (constant 2010 US$)
# 261  Congo, Dem. Rep.          COD  GDP at market prices (constant 2010 US$)
# 262            Zambia          ZMB  GDP at market prices (constant 2010 US$)
# 263          Zimbabwe          ZWE  GDP at market prices (constant 2010 US$)
#
# ...

# %%
df2['Country Name']=df2['Country Name'].replace({"Korea, Rep.": "South Korea",  "Iran, Islamic Rep.": "Iran", "Hong Kong SAR, China": "Hong Kong"})

# %%
df2['Country Name'].unique()
# Out:
# array(['Aruba', 'Andorra', 'Afghanistan', 'Angola', 'Albania',
#        'Arab World', 'United Arab Emirates', 'Argentina', 'Armenia',
#        'American Samoa', 'Antigua and Barbuda', 'Australia', 'Austria',
#        'Azerbaijan', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso',
#        'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas, The',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda',
#        'Bolivia', 'Brazil', 'Barbados', 'Brunei Darussalam', 'Bhutan',
#        'Botswana', 'Central African Republic', 'Canada',
#        'Central Europe and the Baltics', 'Switzerland', 'Channel Islands',
#        'Chile', 'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Rep.',
#        'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica',
#        'Caribbean small states', 'Cuba', 'Curacao', 'Cayman Islands',
#        'Cyprus', 'Czech Republic', 'Germany', 'Djibouti', 'Dominica',
#        'Denmark', 'Dominican Republic', 'Algeria',
# ...

# %%
df3=df2.iloc[:,-10:]

# %%
df3
# Out:
#              2006          2007          2008          2009          2010  \
# 0             NaN           NaN           NaN           NaN  2.467704e+09
# 1    4.018196e+09  4.021331e+09  3.675728e+09  3.535389e+09  3.346317e+09
# 2    1.030523e+10  1.172119e+10  1.214448e+10  1.469733e+10  1.593680e+10
# 3    5.581103e+10  6.842044e+10  7.787420e+10  7.975320e+10  8.247091e+10
# 4    9.771760e+09  1.034829e+10  1.112752e+10  1.150029e+10  1.192695e+10
# ..            ...           ...           ...           ...           ...
# 259  2.672565e+10  2.761787e+10  2.872656e+10  2.991436e+10  3.090675e+10
# 260  3.402852e+11  3.585261e+11  3.699668e+11  3.642764e+11  3.753494e+11
# 261  1.650894e+10  1.754232e+10  1.863448e+10  1.916651e+10  2.052329e+10
# 262  1.440569e+10  1.560892e+10  1.682234e+10  1.837342e+10  2.026555e+10
# 263  1.006276e+10  9.695130e+09  7.982103e+09  8.459783e+09  9.422161e+09
#
#              2011          2012          2013          2014          2015
# ...

# %%
df4=df2.iloc[:,0:4]

# %%
df4
# Out:
#          Country Name Country Code                            Indicator Name  \
# 0               Aruba          ABW  GDP at market prices (constant 2010 US$)
# 1             Andorra          AND  GDP at market prices (constant 2010 US$)
# 2         Afghanistan          AFG  GDP at market prices (constant 2010 US$)
# 3              Angola          AGO  GDP at market prices (constant 2010 US$)
# 4             Albania          ALB  GDP at market prices (constant 2010 US$)
# ..                ...          ...                                       ...
# 259       Yemen, Rep.          YEM  GDP at market prices (constant 2010 US$)
# 260      South Africa          ZAF  GDP at market prices (constant 2010 US$)
# 261  Congo, Dem. Rep.          COD  GDP at market prices (constant 2010 US$)
# 262            Zambia          ZMB  GDP at market prices (constant 2010 US$)
# 263          Zimbabwe          ZWE  GDP at market prices (constant 2010 US$)
#
#      Indicator Code
# 0    NY.GDP.MKTP.KD
# ...

# %%
df2=pd.concat([df4,df3],axis=1)

# %%
df2
# Out:
#          Country Name Country Code                            Indicator Name  \
# 0               Aruba          ABW  GDP at market prices (constant 2010 US$)
# 1             Andorra          AND  GDP at market prices (constant 2010 US$)
# 2         Afghanistan          AFG  GDP at market prices (constant 2010 US$)
# 3              Angola          AGO  GDP at market prices (constant 2010 US$)
# 4             Albania          ALB  GDP at market prices (constant 2010 US$)
# ..                ...          ...                                       ...
# 259       Yemen, Rep.          YEM  GDP at market prices (constant 2010 US$)
# 260      South Africa          ZAF  GDP at market prices (constant 2010 US$)
# 261  Congo, Dem. Rep.          COD  GDP at market prices (constant 2010 US$)
# 262            Zambia          ZMB  GDP at market prices (constant 2010 US$)
# 263          Zimbabwe          ZWE  GDP at market prices (constant 2010 US$)
#
# ...

# %%
df3=pd.read_excel(r"C:\Users\ASUS\Downloads\scimagojr-3.xlsx")

# %%
df3=df3.sort_values(by='Rank',ascending=True)

# %%
df3
# Out:
#      Rank             Country  Documents  Citable documents  Citations  \
# 0       1               China     127050             126767     597237
# 1       2       United States      96661              94747     792274
# 2       3               Japan      30504              30287     223024
# 3       4      United Kingdom      20944              20357     206091
# 4       5  Russian Federation      18534              18301      34266
# ..    ...                 ...        ...                ...        ...
# 186   187              Guyana          1                  1          0
# 187   188    Christmas Island          1                  1          0
# 188   189             Reunion          1                  1          2
# 189   190         Saint Lucia          1                  1          0
# 190   191          Mauritania          1                  1          1
#
#      Self-citations  Citations per document  H index
# 0            411683                    4.70      138
# ...

# %%
df3=df3.head(15)

# %%
df3
# Out:
#     Rank             Country  Documents  Citable documents  Citations  \
# 0      1               China     127050             126767     597237
# 1      2       United States      96661              94747     792274
# 2      3               Japan      30504              30287     223024
# 3      4      United Kingdom      20944              20357     206091
# 4      5  Russian Federation      18534              18301      34266
# 5      6              Canada      17899              17620     215003
# 6      7             Germany      17027              16831     140566
# 7      8               India      15005              14841     128763
# 8      9              France      13153              12973     130632
# 9     10         South Korea      11983              11923     114675
# 10    11               Italy      10964              10794     111850
# 11    12               Spain       9428               9330     123336
# ...

# %%
df2
# Out:
#          Country Name Country Code                            Indicator Name  \
# 0               Aruba          ABW  GDP at market prices (constant 2010 US$)
# 1             Andorra          AND  GDP at market prices (constant 2010 US$)
# 2         Afghanistan          AFG  GDP at market prices (constant 2010 US$)
# 3              Angola          AGO  GDP at market prices (constant 2010 US$)
# 4             Albania          ALB  GDP at market prices (constant 2010 US$)
# ..                ...          ...                                       ...
# 259       Yemen, Rep.          YEM  GDP at market prices (constant 2010 US$)
# 260      South Africa          ZAF  GDP at market prices (constant 2010 US$)
# 261  Congo, Dem. Rep.          COD  GDP at market prices (constant 2010 US$)
# 262            Zambia          ZMB  GDP at market prices (constant 2010 US$)
# 263          Zimbabwe          ZWE  GDP at market prices (constant 2010 US$)
#
# ...

# %%
df2.rename(columns={'Country Name':'Country'},inplace=True)

# %%
df2
# Out:
#               Country Country Code                            Indicator Name  \
# 0               Aruba          ABW  GDP at market prices (constant 2010 US$)
# 1             Andorra          AND  GDP at market prices (constant 2010 US$)
# 2         Afghanistan          AFG  GDP at market prices (constant 2010 US$)
# 3              Angola          AGO  GDP at market prices (constant 2010 US$)
# 4             Albania          ALB  GDP at market prices (constant 2010 US$)
# ..                ...          ...                                       ...
# 259       Yemen, Rep.          YEM  GDP at market prices (constant 2010 US$)
# 260      South Africa          ZAF  GDP at market prices (constant 2010 US$)
# 261  Congo, Dem. Rep.          COD  GDP at market prices (constant 2010 US$)
# 262            Zambia          ZMB  GDP at market prices (constant 2010 US$)
# 263          Zimbabwe          ZWE  GDP at market prices (constant 2010 US$)
#
# ...

# %%
df
# Out:
#             Country  Energy Supply  Energy Supply per Capita  % Renewable
# 17      Afghanistan   3.210000e+08                      10.0    78.669280
# 18          Albania   1.020000e+08                      35.0   100.000000
# 19          Algeria   1.959000e+09                      51.0     0.551010
# 20   American Samoa            NaN                       NaN     0.641026
# 21          Andorra   9.000000e+06                     121.0    88.695650
# ..              ...            ...                       ...          ...
# 277             nan            NaN                       NaN          NaN
# 278             nan            NaN                       NaN          NaN
# 279             nan            NaN                       NaN          NaN
# 280             nan            NaN                       NaN          NaN
# 281             nan            NaN                       NaN          NaN
#
# [265 rows x 4 columns]

# %%
data=pd.merge(df,df2,on='Country')

# %%
data
# Out:
#             Country  Energy Supply  Energy Supply per Capita  % Renewable  \
# 0       Afghanistan   3.210000e+08                      10.0    78.669280
# 1           Albania   1.020000e+08                      35.0   100.000000
# 2           Algeria   1.959000e+09                      51.0     0.551010
# 3    American Samoa            NaN                       NaN     0.641026
# 4           Andorra   9.000000e+06                     121.0    88.695650
# ..              ...            ...                       ...          ...
# 178         Uruguay   1.960000e+08                      58.0    71.605040
# 179      Uzbekistan   1.798000e+09                      62.0    21.328410
# 180         Vanuatu   3.000000e+06                      10.0    14.705880
# 181          Zambia   4.000000e+08                      26.0    99.714670
# 182        Zimbabwe   4.800000e+08                      32.0    52.536120
#
#     Country Code                            Indicator Name  Indicator Code  \
# ...

# %%
df=pd.merge(data,df3)

# %%
df
# Out:
#                Country  Energy Supply  Energy Supply per Capita  % Renewable  \
# 0            Australia   5.386000e+09                     231.0    11.810810
# 1               Brazil   1.214900e+10                      59.0    69.648030
# 2               Canada   1.043100e+10                     296.0    61.945430
# 3                China   1.271910e+11                      93.0    19.754910
# 4               France   1.059700e+10                     166.0    17.020280
# 5              Germany   1.326100e+10                     165.0    17.901530
# 6                India   3.319500e+10                      26.0    14.969080
# 7                 Iran   9.172000e+09                     119.0     5.707721
# 8                Italy   6.530000e+09                     109.0    33.667230
# 9                Japan   1.898400e+10                     149.0    10.232820
# 10         South Korea   1.100700e+10                     221.0     2.279353
# ...

# %%
df.drop(columns=['Indicator Name','Indicator Code','Country Code'],inplace=True)

# %%
df
# Out:
#                Country  Energy Supply  Energy Supply per Capita  % Renewable  \
# 0            Australia   5.386000e+09                     231.0    11.810810
# 1               Brazil   1.214900e+10                      59.0    69.648030
# 2               Canada   1.043100e+10                     296.0    61.945430
# 3                China   1.271910e+11                      93.0    19.754910
# 4               France   1.059700e+10                     166.0    17.020280
# 5              Germany   1.326100e+10                     165.0    17.901530
# 6                India   3.319500e+10                      26.0    14.969080
# 7                 Iran   9.172000e+09                     119.0     5.707721
# 8                Italy   6.530000e+09                     109.0    33.667230
# 9                Japan   1.898400e+10                     149.0    10.232820
# 10         South Korea   1.100700e+10                     221.0     2.279353
# ...

# %%
df.set_index('Country',inplace=True)

# %%
df
# Out:
#                     Energy Supply  Energy Supply per Capita  % Renewable  \
# Country
# Australia            5.386000e+09                     231.0    11.810810
# Brazil               1.214900e+10                      59.0    69.648030
# Canada               1.043100e+10                     296.0    61.945430
# China                1.271910e+11                      93.0    19.754910
# France               1.059700e+10                     166.0    17.020280
# Germany              1.326100e+10                     165.0    17.901530
# India                3.319500e+10                      26.0    14.969080
# Iran                 9.172000e+09                     119.0     5.707721
# Italy                6.530000e+09                     109.0    33.667230
# Japan                1.898400e+10                     149.0    10.232820
# South Korea          1.100700e+10                     221.0     2.279353
# Russian Federation   3.070900e+10                     214.0    17.288680
# ...

# %%
df.shape
# Out:
# (13, 20)

# %%
df.sort_values(by='Rank',inplace=True)

# %%
df
# Out:
#                     Energy Supply  Energy Supply per Capita  % Renewable  \
# Country
# China                1.271910e+11                      93.0    19.754910
# Japan                1.898400e+10                     149.0    10.232820
# Russian Federation   3.070900e+10                     214.0    17.288680
# Canada               1.043100e+10                     296.0    61.945430
# Germany              1.326100e+10                     165.0    17.901530
# India                3.319500e+10                      26.0    14.969080
# France               1.059700e+10                     166.0    17.020280
# South Korea          1.100700e+10                     221.0     2.279353
# Italy                6.530000e+09                     109.0    33.667230
# Spain                4.923000e+09                     106.0    37.968590
# Iran                 9.172000e+09                     119.0     5.707721
# Australia            5.386000e+09                     231.0    11.810810
# ...

# %%
df3
# Out:
#     Rank             Country  Documents  Citable documents  Citations  \
# 0      1               China     127050             126767     597237
# 1      2       United States      96661              94747     792274
# 2      3               Japan      30504              30287     223024
# 3      4      United Kingdom      20944              20357     206091
# 4      5  Russian Federation      18534              18301      34266
# 5      6              Canada      17899              17620     215003
# 6      7             Germany      17027              16831     140566
# 7      8               India      15005              14841     128763
# 8      9              France      13153              12973     130632
# 9     10         South Korea      11983              11923     114675
# 10    11               Italy      10964              10794     111850
# 11    12               Spain       9428               9330     123336
# ...

# %%
df
# Out:
#                     Energy Supply  Energy Supply per Capita  % Renewable  \
# Country
# China                1.271910e+11                      93.0    19.754910
# Japan                1.898400e+10                     149.0    10.232820
# Russian Federation   3.070900e+10                     214.0    17.288680
# Canada               1.043100e+10                     296.0    61.945430
# Germany              1.326100e+10                     165.0    17.901530
# India                3.319500e+10                      26.0    14.969080
# France               1.059700e+10                     166.0    17.020280
# South Korea          1.100700e+10                     221.0     2.279353
# Italy                6.530000e+09                     109.0    33.667230
# Spain                4.923000e+09                     106.0    37.968590
# Iran                 9.172000e+09                     119.0     5.707721
# Australia            5.386000e+09                     231.0    11.810810
# ...

# %%
df.describe()
# Out:
#        Energy Supply  Energy Supply per Capita  % Renewable          2006  \
# count   1.300000e+01                 13.000000    13.000000  1.300000e+01
# mean    2.257962e+10                150.307692    24.630343  2.112334e+12
# std     3.266076e+10                 75.817088    20.780687  1.424838e+12
# min     4.923000e+09                 26.000000     2.279353  3.895523e+11
# 25%     9.172000e+09                106.000000    11.810810  1.265894e+12
# 50%     1.100700e+10                149.000000    17.288680  1.564469e+12
# 75%     1.898400e+10                214.000000    33.667230  2.607840e+12
# max     1.271910e+11                296.000000    69.648030  5.496542e+12
#
#                2007          2008          2009          2010          2011  \
# count  1.300000e+01  1.300000e+01  1.300000e+01  1.300000e+01  1.300000e+01
# mean   2.223113e+12  2.279651e+12  2.255817e+12  2.378440e+12  2.465087e+12
# ...

# %%
avgGDP=pd.Series(['China','United States','Japan','Germany','United Kingdom','France','Brazil','Italy','India','Canada','Russian Federation','Spain','Australia','South Korea','Iran'])

# %%
avgGDP
# Out:
# 0                  China
# 1          United States
# 2                  Japan
# 3                Germany
# 4         United Kingdom
# 5                 France
# 6                 Brazil
# 7                  Italy
# 8                  India
# 9                 Canada
# 10    Russian Federation
# 11                 Spain
# 12             Australia
# 13           South Korea
# 14                  Iran
# dtype: object

# %%
df
# Out:
#                     Energy Supply  Energy Supply per Capita  % Renewable  \
# Country
# China                1.271910e+11                      93.0    19.754910
# Japan                1.898400e+10                     149.0    10.232820
# Russian Federation   3.070900e+10                     214.0    17.288680
# Canada               1.043100e+10                     296.0    61.945430
# Germany              1.326100e+10                     165.0    17.901530
# India                3.319500e+10                      26.0    14.969080
# France               1.059700e+10                     166.0    17.020280
# South Korea          1.100700e+10                     221.0     2.279353
# Italy                6.530000e+09                     109.0    33.667230
# Spain                4.923000e+09                     106.0    37.968590
# Iran                 9.172000e+09                     119.0     5.707721
# Australia            5.386000e+09                     231.0    11.810810
# ...

# %%
dfn=df['2015']-df['2006']

# %%
dfn
# Out:
# Country
# China                 4.805667e+12
# Japan                 1.730216e+11
# Russian Federation    2.303563e+11
# Canada                2.281399e+11
# Germany               3.526652e+11
# India                 1.101312e+12
# France                1.533457e+11
# South Korea           3.255605e+11
# Italy                -1.528541e+11
# Spain                 4.998675e+09
# Iran                           NaN
# Australia             2.793118e+11
# Brazil                4.743437e+11
# dtype: float64

# %%
df['Energy Supply per Capita'].mean()
# Out:
# 150.30769230769232

# %%
df.sort_values(by='% Renewable')
# Out:
#                     Energy Supply  Energy Supply per Capita  % Renewable  \
# Country
# South Korea          1.100700e+10                     221.0     2.279353
# Iran                 9.172000e+09                     119.0     5.707721
# Japan                1.898400e+10                     149.0    10.232820
# Australia            5.386000e+09                     231.0    11.810810
# India                3.319500e+10                      26.0    14.969080
# France               1.059700e+10                     166.0    17.020280
# Russian Federation   3.070900e+10                     214.0    17.288680
# Germany              1.326100e+10                     165.0    17.901530
# China                1.271910e+11                      93.0    19.754910
# Italy                6.530000e+09                     109.0    33.667230
# Spain                4.923000e+09                     106.0    37.968590
# Canada               1.043100e+10                     296.0    61.945430
# ...

# %%
df
# Out:
#                     Energy Supply  Energy Supply per Capita  % Renewable  \
# Country
# China                1.271910e+11                      93.0    19.754910
# Japan                1.898400e+10                     149.0    10.232820
# Russian Federation   3.070900e+10                     214.0    17.288680
# Canada               1.043100e+10                     296.0    61.945430
# Germany              1.326100e+10                     165.0    17.901530
# India                3.319500e+10                      26.0    14.969080
# France               1.059700e+10                     166.0    17.020280
# South Korea          1.100700e+10                     221.0     2.279353
# Italy                6.530000e+09                     109.0    33.667230
# Spain                4.923000e+09                     106.0    37.968590
# Iran                 9.172000e+09                     119.0     5.707721
# Australia            5.386000e+09                     231.0    11.810810
# ...

# %%
x=df.iloc[:,3:13]

# %%
x
# Out:
#                             2006          2007          2008          2009  \
# Country
# China               3.992331e+12  4.559041e+12  4.997775e+12  5.459247e+12
# Japan               5.496542e+12  5.617036e+12  5.558527e+12  5.251308e+12
# Russian Federation  1.385793e+12  1.504071e+12  1.583004e+12  1.459199e+12
# Canada              1.564469e+12  1.596740e+12  1.612713e+12  1.565145e+12
# Germany             3.332891e+12  3.441561e+12  3.478809e+12  3.283340e+12
# India               1.265894e+12  1.374865e+12  1.428361e+12  1.549483e+12
# France              2.607840e+12  2.669424e+12  2.674637e+12  2.595967e+12
# South Korea         9.410199e+11  9.924316e+11  1.020510e+12  1.027730e+12
# Italy               2.202170e+12  2.234627e+12  2.211154e+12  2.089938e+12
# Spain               1.414823e+12  1.468146e+12  1.484530e+12  1.431475e+12
# Iran                3.895523e+11  4.250646e+11  4.289909e+11  4.389208e+11
# ...

# %%
df
# Out:
#                     Energy Supply  Energy Supply per Capita  % Renewable  \
# Country
# China                1.271910e+11                      93.0    19.754910
# Japan                1.898400e+10                     149.0    10.232820
# Russian Federation   3.070900e+10                     214.0    17.288680
# Canada               1.043100e+10                     296.0    61.945430
# Germany              1.326100e+10                     165.0    17.901530
# India                3.319500e+10                      26.0    14.969080
# France               1.059700e+10                     166.0    17.020280
# South Korea          1.100700e+10                     221.0     2.279353
# Italy                6.530000e+09                     109.0    33.667230
# Spain                4.923000e+09                     106.0    37.968590
# Iran                 9.172000e+09                     119.0     5.707721
# Australia            5.386000e+09                     231.0    11.810810
# ...

# %%
x
# Out:
#                             2006          2007          2008          2009  \
# Country
# China               3.992331e+12  4.559041e+12  4.997775e+12  5.459247e+12
# Japan               5.496542e+12  5.617036e+12  5.558527e+12  5.251308e+12
# Russian Federation  1.385793e+12  1.504071e+12  1.583004e+12  1.459199e+12
# Canada              1.564469e+12  1.596740e+12  1.612713e+12  1.565145e+12
# Germany             3.332891e+12  3.441561e+12  3.478809e+12  3.283340e+12
# India               1.265894e+12  1.374865e+12  1.428361e+12  1.549483e+12
# France              2.607840e+12  2.669424e+12  2.674637e+12  2.595967e+12
# South Korea         9.410199e+11  9.924316e+11  1.020510e+12  1.027730e+12
# Italy               2.202170e+12  2.234627e+12  2.211154e+12  2.089938e+12
# Spain               1.414823e+12  1.468146e+12  1.484530e+12  1.431475e+12
# Iran                3.895523e+11  4.250646e+11  4.289909e+11  4.389208e+11
# ...

# %%
x.drop('sum',inplace=True,axis=1)

# %%
x
# Out:
#                             2006          2007          2008          2009  \
# Country
# China               3.992331e+12  4.559041e+12  4.997775e+12  5.459247e+12
# Japan               5.496542e+12  5.617036e+12  5.558527e+12  5.251308e+12
# Russian Federation  1.385793e+12  1.504071e+12  1.583004e+12  1.459199e+12
# Canada              1.564469e+12  1.596740e+12  1.612713e+12  1.565145e+12
# Germany             3.332891e+12  3.441561e+12  3.478809e+12  3.283340e+12
# India               1.265894e+12  1.374865e+12  1.428361e+12  1.549483e+12
# France              2.607840e+12  2.669424e+12  2.674637e+12  2.595967e+12
# South Korea         9.410199e+11  9.924316e+11  1.020510e+12  1.027730e+12
# Italy               2.202170e+12  2.234627e+12  2.211154e+12  2.089938e+12
# Spain               1.414823e+12  1.468146e+12  1.484530e+12  1.431475e+12
# Iran                3.895523e+11  4.250646e+11  4.289909e+11  4.389208e+11
# ...

# %%
df.mean(axis=1)
# Out:
# Country
# China                 3.180664e+12
# Japan                 2.772053e+12
# Russian Federation    7.842652e+11
# Canada                8.308453e+11
# Germany               1.747176e+12
# India                 8.863085e+11
# France                1.341392e+12
# South Korea           5.539076e+11
# Italy                 1.060414e+12
# Spain                 7.092853e+11
# Iran                  2.108723e+11
# Australia             5.822907e+11
# Brazil                1.095505e+12
# dtype: float64

# %%
df.sort_values(by='Rank')
# Out:
#                     Energy Supply  Energy Supply per Capita  % Renewable  \
# Country
# China                1.271910e+11                      93.0    19.754910
# Japan                1.898400e+10                     149.0    10.232820
# Russian Federation   3.070900e+10                     214.0    17.288680
# Canada               1.043100e+10                     296.0    61.945430
# Germany              1.326100e+10                     165.0    17.901530
# India                3.319500e+10                      26.0    14.969080
# France               1.059700e+10                     166.0    17.020280
# South Korea          1.100700e+10                     221.0     2.279353
# Italy                6.530000e+09                     109.0    33.667230
# Spain                4.923000e+09                     106.0    37.968590
# Iran                 9.172000e+09                     119.0     5.707721
# Australia            5.386000e+09                     231.0    11.810810
# ...

# %%
df['2015']-df['2006']
# Out:
# Country
# China                 4.805667e+12
# Japan                 1.730216e+11
# Russian Federation    2.303563e+11
# Canada                2.281399e+11
# Germany               3.526652e+11
# India                 1.101312e+12
# France                1.533457e+11
# South Korea           3.255605e+11
# Italy                -1.528541e+11
# Spain                 4.998675e+09
# Iran                           NaN
# Australia             2.793118e+11
# Brazil                4.743437e+11
# dtype: float64

# %%
df
# Out:
#                     Energy Supply  Energy Supply per Capita  % Renewable  \
# Country
# China                1.271910e+11                      93.0    19.754910
# Japan                1.898400e+10                     149.0    10.232820
# Russian Federation   3.070900e+10                     214.0    17.288680
# Canada               1.043100e+10                     296.0    61.945430
# Germany              1.326100e+10                     165.0    17.901530
# India                3.319500e+10                      26.0    14.969080
# France               1.059700e+10                     166.0    17.020280
# South Korea          1.100700e+10                     221.0     2.279353
# Italy                6.530000e+09                     109.0    33.667230
# Spain                4.923000e+09                     106.0    37.968590
# Iran                 9.172000e+09                     119.0     5.707721
# Australia            5.386000e+09                     231.0    11.810810
# ...

# %%
df.mean()
# Out:
# Energy Supply               2.257962e+10
# Energy Supply per Capita    1.503077e+02
# % Renewable                 2.463034e+01
# 2006                        2.112334e+12
# 2007                        2.223113e+12
# 2008                        2.279651e+12
# 2009                        2.255817e+12
# 2010                        2.378440e+12
# 2011                        2.465087e+12
# 2012                        2.526431e+12
# 2013                        2.595758e+12
# 2014                        2.667100e+12
# 2015                        2.920555e+12
# Rank                        8.769231e+00
# Documents                   2.291862e+04
# Citable documents           2.275438e+04
# Citations                   1.560222e+05
# Self-citations              5.709015e+04
# Citations per document      8.402308e+00
# H index                     1.094615e+02
# sum                                  NaN
# dtype: float64

# %%
df['% Renewable'].max()
# Out:
# 69.64803

# %%
df[df['% Renewable']==df['% Renewable'].max()]
# Out:
#          Energy Supply  Energy Supply per Capita  % Renewable          2006  \
# Country
# Brazil    1.214900e+10                      59.0     69.64803  1.845080e+12
#
#                  2007          2008          2009          2010          2011  \
# Country
# Brazil   1.957118e+12  2.056809e+12  2.054215e+12  2.208872e+12  2.295245e+12
#
#                  2012  ...          2014          2015  Rank  Documents  \
# Country                ...
# Brazil   2.339209e+12  ...  2.412231e+12  2.319423e+12    15       8668
#
#          Citable documents  Citations  Self-citations  Citations per document  \
# Country
# Brazil                8596      60702           14396                     7.0
#
#          H index  sum
# Country
# Brazil        86  NaN
#
# [1 rows x 21 columns]

# %%
df['NEW']=df['Self-citations']/df['Citations']

# %%
df
# Out:
#                     Energy Supply  Energy Supply per Capita  % Renewable  \
# Country
# China                1.271910e+11                      93.0    19.754910
# Japan                1.898400e+10                     149.0    10.232820
# Russian Federation   3.070900e+10                     214.0    17.288680
# Canada               1.043100e+10                     296.0    61.945430
# Germany              1.326100e+10                     165.0    17.901530
# India                3.319500e+10                      26.0    14.969080
# France               1.059700e+10                     166.0    17.020280
# South Korea          1.100700e+10                     221.0     2.279353
# Italy                6.530000e+09                     109.0    33.667230
# Spain                4.923000e+09                     106.0    37.968590
# Iran                 9.172000e+09                     119.0     5.707721
# Australia            5.386000e+09                     231.0    11.810810
# ...

# %%
df[df['NEW']==df['NEW'].max()]
# Out:
#          Energy Supply  Energy Supply per Capita  % Renewable          2006  \
# Country
# China     1.271910e+11                      93.0     19.75491  3.992331e+12
#
#                  2007          2008          2009          2010          2011  \
# Country
# China    4.559041e+12  4.997775e+12  5.459247e+12  6.039659e+12  6.612490e+12
#
#                  2012  ...          2015  Rank  Documents  Citable documents  \
# Country                ...
# China    7.124978e+12  ...  8.797999e+12     1     127050             126767
#
#          Citations  Self-citations  Citations per document  H index  sum  \
# Country
# China       597237          411683                     4.7      138  NaN
#
#               NEW
# Country
# China    0.689313
#
# [1 rows x 22 columns]

# %%
df
# Out:
#                     Energy Supply  Energy Supply per Capita  % Renewable  \
# Country
# China                1.271910e+11                      93.0    19.754910
# Japan                1.898400e+10                     149.0    10.232820
# Russian Federation   3.070900e+10                     214.0    17.288680
# Canada               1.043100e+10                     296.0    61.945430
# Germany              1.326100e+10                     165.0    17.901530
# India                3.319500e+10                      26.0    14.969080
# France               1.059700e+10                     166.0    17.020280
# South Korea          1.100700e+10                     221.0     2.279353
# Italy                6.530000e+09                     109.0    33.667230
# Spain                4.923000e+09                     106.0    37.968590
# Iran                 9.172000e+09                     119.0     5.707721
# Australia            5.386000e+09                     231.0    11.810810
# ...

# %%
df['new']=df['Energy Supply']/df['Energy Supply per Capita']

# %%
df
# Out:
#                     Energy Supply  Energy Supply per Capita  % Renewable  \
# Country
# China                1.271910e+11                      93.0    19.754910
# Japan                1.898400e+10                     149.0    10.232820
# Russian Federation   3.070900e+10                     214.0    17.288680
# Canada               1.043100e+10                     296.0    61.945430
# Germany              1.326100e+10                     165.0    17.901530
# India                3.319500e+10                      26.0    14.969080
# France               1.059700e+10                     166.0    17.020280
# South Korea          1.100700e+10                     221.0     2.279353
# Italy                6.530000e+09                     109.0    33.667230
# Spain                4.923000e+09                     106.0    37.968590
# Iran                 9.172000e+09                     119.0     5.707721
# Australia            5.386000e+09                     231.0    11.810810
# ...

# %%
df[df['new']==df['new'].max()]
# Out:
#          Energy Supply  Energy Supply per Capita  % Renewable          2006  \
# Country
# China     1.271910e+11                      93.0     19.75491  3.992331e+12
#
#                  2007          2008          2009          2010          2011  \
# Country
# China    4.559041e+12  4.997775e+12  5.459247e+12  6.039659e+12  6.612490e+12
#
#                  2012  ...  Rank  Documents  Citable documents  Citations  \
# Country                ...
# China    7.124978e+12  ...     1     127050             126767     597237
#
#          Self-citations  Citations per document  H index  sum       NEW  \
# Country
# China            411683                     4.7      138  NaN  0.689313
#
#                   new
# Country
# China    1.367645e+09
#
# [1 rows x 23 columns]

# %%
df.head(1)
# Out:
#          Energy Supply  Energy Supply per Capita  % Renewable          2006  \
# Country
# China     1.271910e+11                      93.0     19.75491  3.992331e+12
#
#                  2007          2008          2009          2010          2011  \
# Country
# China    4.559041e+12  4.997775e+12  5.459247e+12  6.039659e+12  6.612490e+12
#
#                  2012  ...  Rank  Documents  Citable documents  Citations  \
# Country                ...
# China    7.124978e+12  ...     1     127050             126767     597237
#
#          Self-citations  Citations per document  H index  sum       NEW  \
# Country
# China            411683                     4.7      138  NaN  0.689313
#
#                   new
# Country
# China    1.367645e+09
#
# [1 rows x 23 columns]

# %%
p=1.728868e+01

# %%
con={'China':'Asia', 
                  'United States':'North America', 
                  'Japan':'Asia', 
                  'United Kingdom':'Europe', 
                  'Russian Federation':'Europe', 
                  'Canada':'North America', 
                  'Germany':'Europe', 
                  'India':'Asia',
                  'France':'Europe', 
                  'South Korea':'Asia', 
                  'Italy':'Europe', 
                  'Spain':'Europe', 
                  'Iran':'Asia',
                  'Australia':'Australia', 
                  'Brazil':'South America'}

# %%
def con(x):
    return
